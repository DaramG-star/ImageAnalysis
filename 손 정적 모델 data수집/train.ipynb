# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np

# CSV 불러오기
df = pd.read_csv("hand_landmarks.csv")

# 라벨과 좌표 분리
X = df.drop("label", axis=1).values.astype(np.float32)
y = df["label"].values

# 라벨 인코딩 (문자 → 숫자)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# 학습 / 검증 분리
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential([
    Dense(128, activation='relu', input_shape=(X.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(len(label_encoder.classes_), activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:From c:\Users\SSAFY\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\SSAFY\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\SSAFY\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=30,
    batch_size=32
)
# Out:
# Epoch 1/30
# WARNING:tensorflow:From c:\Users\SSAFY\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\SSAFY\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3170/3170 [==============================] - 5s 1ms/step - loss: 0.7061 - accuracy: 0.7758 - val_loss: 0.2471 - val_accuracy: 0.9398
# Epoch 2/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.2769 - accuracy: 0.9266 - val_loss: 0.1470 - val_accuracy: 0.9612
# Epoch 3/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.2020 - accuracy: 0.9468 - val_loss: 0.1166 - val_accuracy: 0.9707
# Epoch 4/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.1712 - accuracy: 0.9564 - val_loss: 0.0963 - val_accuracy: 0.9775
# Epoch 5/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.1484 - accuracy: 0.9619 - val_loss: 0.0870 - val_accuracy: 0.9797
# Epoch 6/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.1366 - accuracy: 0.9652 - val_loss: 0.0773 - val_accuracy: 0.9822
# Epoch 7/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.1247 - accuracy: 0.9677 - val_loss: 0.0749 - val_accuracy: 0.9822
# Epoch 8/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.1199 - accuracy: 0.9690 - val_loss: 0.0752 - val_accuracy: 0.9832
# Epoch 9/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.1141 - accuracy: 0.9715 - val_loss: 0.0637 - val_accuracy: 0.9850
# Epoch 10/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.1080 - accuracy: 0.9721 - val_loss: 0.0658 - val_accuracy: 0.9851
# Epoch 11/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.1054 - accuracy: 0.9734 - val_loss: 0.0609 - val_accuracy: 0.9853
# Epoch 12/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.1005 - accuracy: 0.9739 - val_loss: 0.0607 - val_accuracy: 0.9864
# Epoch 13/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0969 - accuracy: 0.9749 - val_loss: 0.0570 - val_accuracy: 0.9867
# Epoch 14/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0964 - accuracy: 0.9750 - val_loss: 0.0570 - val_accuracy: 0.9865
# Epoch 15/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0917 - accuracy: 0.9759 - val_loss: 0.0576 - val_accuracy: 0.9865
# Epoch 16/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0925 - accuracy: 0.9762 - val_loss: 0.0527 - val_accuracy: 0.9878
# Epoch 17/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0889 - accuracy: 0.9765 - val_loss: 0.0515 - val_accuracy: 0.9874
# Epoch 18/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0878 - accuracy: 0.9771 - val_loss: 0.0507 - val_accuracy: 0.9874
# Epoch 19/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0873 - accuracy: 0.9769 - val_loss: 0.0481 - val_accuracy: 0.9883
# Epoch 20/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0847 - accuracy: 0.9776 - val_loss: 0.0525 - val_accuracy: 0.9877
# Epoch 21/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0852 - accuracy: 0.9775 - val_loss: 0.0500 - val_accuracy: 0.9879
# Epoch 22/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0813 - accuracy: 0.9788 - val_loss: 0.0499 - val_accuracy: 0.9877
# Epoch 23/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0835 - accuracy: 0.9780 - val_loss: 0.0489 - val_accuracy: 0.9882
# Epoch 24/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0813 - accuracy: 0.9783 - val_loss: 0.0457 - val_accuracy: 0.9882
# Epoch 25/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0791 - accuracy: 0.9789 - val_loss: 0.0470 - val_accuracy: 0.9886
# Epoch 26/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0801 - accuracy: 0.9790 - val_loss: 0.0470 - val_accuracy: 0.9879
# Epoch 27/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0794 - accuracy: 0.9792 - val_loss: 0.0458 - val_accuracy: 0.9890
# Epoch 28/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0762 - accuracy: 0.9796 - val_loss: 0.0446 - val_accuracy: 0.9890
# Epoch 29/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0766 - accuracy: 0.9797 - val_loss: 0.0439 - val_accuracy: 0.9892
# Epoch 30/30
# 3170/3170 [==============================] - 4s 1ms/step - loss: 0.0779 - accuracy: 0.9794 - val_loss: 0.0441 - val_accuracy: 0.9892

# %%
model.save("gesture_model7.h5")
np.save("gesture_labels7.npy", label_encoder.classes_)
# Out:
# c:\Users\SSAFY\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import tensorflow as tf

# 1. Keras 모델 로드
model = tf.keras.models.load_model("gesture_model5.h5")

# 2. TFLite Converter 생성
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# 3. (선택) 최적화 적용 - 용량 줄이고 속도 향상
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# 4. 변환 수행
tflite_model = converter.convert()

# 5. 저장
with open("gesture_model5.tflite", "wb") as f:
    f.write(tflite_model)

print("✅ gesture_model5.tflite 저장 완료!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:AutoGraph could not transform <function TFLayer._default_save_signature.<locals>.serving_default at 0x0000020BA9D1D750> and will run it as-is.
# Cause: Unable to locate the source code of <function TFLayer._default_save_signature.<locals>.serving_default at 0x0000020BA9D1D750>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TFLayer._default_save_signature.<locals>.serving_default at 0x0000020BA9D1D750> and will run it as-is.
# Cause: Unable to locate the source code of <function TFLayer._default_save_signature.<locals>.serving_default at 0x0000020BA9D1D750>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TFLayer._default_save_signature.<locals>.serving_default at 0x0000020BA9D1D750> and will run it as-is.
# Cause: Unable to locate the source code of <function TFLayer._default_save_signature.<locals>.serving_default at 0x0000020BA9D1D750>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TFLayer._default_save_signature.<locals>.serving_default at 0x0000020BA9D1E0E0> and will run it as-is.
# Cause: Unable to locate the source code of <function TFLayer._default_save_signature.<locals>.serving_default at 0x0000020BA9D1E0E0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TFLayer._default_save_signature.<locals>.serving_default at 0x0000020BA9D1E0E0> and will run it as-is.
# Cause: Unable to locate the source code of <function TFLayer._default_save_signature.<locals>.serving_default at 0x0000020BA9D1E0E0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TFLayer._default_save_signature.<locals>.serving_default at 0x0000020BA9D1E0E0> and will run it as-is.
# Cause: Unable to locate the source code of <function TFLayer._default_save_signature.<locals>.serving_default at 0x0000020BA9D1E0E0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# INFO:tensorflow:Assets written to: C:\Users\SSAFY\AppData\Local\Temp\tmpdnm6ezc3\assets
# INFO:tensorflow:Assets written to: C:\Users\SSAFY\AppData\Local\Temp\tmpdnm6ezc3\assets
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
